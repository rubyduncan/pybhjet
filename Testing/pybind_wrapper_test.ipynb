# %%
#for the testing dir
import sys
sys.path.append("/Users/ruby/Models/PyBHJet")

import build.pybhjet as pybhjet
import numpy as np
import math
import matplotlib.pyplot as plt
from bhjet_plotting import *

bhjet = pybhjet.PyBHJet()

# %%
bhjet.load_params("../ip.dat")
bhjet.set_parameter("infosw", 2)

# %%
bhjet.run()

#need to call for the output to be accessible 
output = bhjet.get_output()

#get the emission components into dictionaries to plot easier 
components = preprocess_component_output(output)

# %%
bhjet.print_parameters()
# Out:
# BHJet Parameters:
# -----------------
# Mbh      : 6.6e+08     M_sun
# theta    : 66          degrees
# dist     : 9080        kpc
# redsh    : 0.003633
# jetrat   : 0.00064     Eddington ratio
# r_0      : 7.72058     Jet base radius, R_g
# z_diss   : 24.971      nT particle injection region, R_g
# z_acc    : 24.971      Jet acceleration region, R_g
# z_max    : 100000      Maximum Jet Distance, R_g
# t_e      : 655.986     Temperature of rel. electrons in nozzle, keV
# f_nth    : 0.1         Percentage of particles acc. into nT tail
# f_pl     : 4.67634     Dissipation Parameter
# pspec    : 1.5         Slope of nT lepton distribution
# f_heat   : 16.247      Shock Heating
# f_beta   : 0.1         Adiabatic Cooling Timescale
# f_sc     : 7.98968e-09  < 0.1, Max. E of nT particles
# p_beta   : 0.02        Plasma Beta [Regulates Pair Content in BHJet for velsw > 1]
# sig_acc  : 0.01        Magnetization at acceleration region
# l_disk   : 2.3e-06     Disk Luminosity, L_edd
# r_in     : 20          Inner Disk Radius, R_g
# r_out    : 1000        Outer Disk Radius, R_g
# compar1  : 2736.15     Compsw=1: Temp of BB [K], Compsw=2: % of disk photons reprocessed by BLR
# compar2  : 1.69379e+37 Compsw=1: Lum of BB [ergs], Compsw=2: % of disk photons reprocessed by torus
# compar3  : 3e-10       Compsw=1: BB Energy Density
# compsw   : 0           Adds Ext. Photon Field, = 1: BB, = 2: BLR & Torus
# velsw    : 6           =0, 1: agnjet(pressure driven), > 1: bljet(magnetic driven)
# infosw   : 2
# EBLsw    : 0           Account for EBL attenuation

# %%
bhjet.set_parameter("infosw", 5)
bhjet.run()
# Out:
# Inner disk radius: 1.94927e+15 cm, 20 rg; outer disk radius: 9.74633e+16 cm, 1000 rg; disk scale height: 0.1
# Inner disk temperature: 0.000394744 kev; emitted  disk luminosity in Eddington units: 2.3e-06 and erg s^-1: 1.88015e+41
#
# Jet base parameters:
# Pair content (ne/np): 21.0933
# Initial magnetization: 4.4524
# Particle average Lorenz factor: 4.12037
# Jet nozzle ends at: 17.4412 Rg
# Jet nozzle optical depth: 0.0020997
#
# Bfield: 133.346 r: 7.52472e+14 z: 1.69987e+15 v.angle: 1.15192 speed: 0.436436 delta: 1.09392
# Optical depth: 0.0020997 Compton-Y: 0.0661477 r: 7.52472e+14 z: 1.69987e+15 angle: 1.15192 speed: 0.436436 delta: 1.09392
# Number of scatters: 1
# Bfield: 32.4423 r: 7.63767e+14 z: 1.50494e+15 v.angle: 1.15192 speed: 0.922558 delta: 0.61761
# Optical depth: 0.00041969 Compton-Y: 0.0132216 r: 7.63767e+14 z: 1.50494e+15 angle: 1.15192 speed: 0.922558 delta: 0.61761
# Number of scatters: 1
# Bfield: 1.26455 r: 7.94978e+14 z: 1.52753e+15 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Optical depth: 0.000162954 Compton-Y: 1.05185 r: 7.94978e+14 z: 1.52753e+15 angle: 1.15192 speed: 0.986013 delta: 0.278264
# Number of scatters: 1
# Bfield: 0.87252 r: 8.33174e+14 z: 1.58996e+15 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Optical depth: 0.
+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0127523 r: 9.13991e+15 z: 2.34637e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0119225 r: 9.72663e+15 z: 2.50967e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0111467 r: 1.03542e+16 z: 2.68434e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0104214 r: 1.10254e+16 z: 2.87117e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00974326 r: 1.17433e+16 z: 3.071e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00910927 r: 1.25113e+16 z: 3.28474e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00851653 r: 1.33326e+16 z: 3.51335e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00796236 r: 1.42111e+16 z: 3.75788e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00744425 r: 1.51508e+16 z: 4.01942e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00695985 r: 1.61559e+16 z: 4.29917e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00650697 r: 1.72309e+16 z: 4.59839e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00608356 r: 1.83807e+16 z: 4.91843e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0056877 r: 1.96106e+16 z: 5.26075e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0053176 r: 2.0926e+16 z: 5.62689e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00497159 r: 2.23331e+16 z: 6.01852e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00464809 r: 2.3838e+16 z: 6.4374e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00434563 r: 2.54477e+16 z: 6.88543e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00406286 r: 2.71694e+16 z: 7.36465e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00379849 r: 2.90109e+16 z: 7.87722e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00355132 r: 3.09807e+16 z: 8.42547e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00332024 r: 3.30875e+16 z: 9.01187e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00310419 r: 3.53409e+16 z: 9.63909e+16 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0029022 r: 3.77512e+16 z: 1.031e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00271336 r: 4.03292e+16 z: 1.10275e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0025368 r: 4.30867e+16 z: 1.1795e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00237173 r: 4.6036e+16 z: 1.26159e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0022174 r: 4.91907e+16 z: 1.3494e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00207311 r: 5.25649e+16 z: 1.44332e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00193821 r: 5.61739e+16 z: 1.54377e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0018121 r: 6.00342e+16 z: 1.65121e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00169418 r: 6.41631e+16 z: 1.76614e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00158394 r: 6.85793e+16 z: 1.88906e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00148087 r: 7.33029e+16 z: 2.02053e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00138451 r: 7.83553e+16 z: 2.16116e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00129442 r: 8.37594e+16 z: 2.31158e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.0012102 r: 8.95395e+16 z: 2.47246e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00113145 r: 9.57219e+16 z: 2.64454e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00105782 r: 1.02335e+17 z: 2.8286e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000988992 r: 1.09408e+17 z: 3.02546e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000924638 r: 1.16973e+17 z: 3.23603e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000864472 r: 1.25065e+17 z: 3.46126e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.00080822 r: 1.3372e+17 z: 3.70216e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000755629 r: 1.42977e+17 z: 3.95982e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000706461 r: 1.52879e+17 z: 4.23542e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000660491 r: 1.63469e+17 z: 4.5302e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000617513 r: 1.74797e+17 z: 4.8455e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000577331 r: 1.86913e+17 z: 5.18274e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000539764 r: 1.99873e+17 z: 5.54345e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000504642 r: 2.13734e+17 z: 5.92927e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region
# Bfield: 0.000471805 r: 2.28561e+17 z: 6.34194e+17 v.angle: 1.15192 speed: 0.986013 delta: 0.278264
# Out of the Comptonization region

# %%
plot_nufnu_ergshz(components, title = 'Test Output')
plt.ylim(1e-17, 1e-11)
plt.xlim(5e8, 1e19)
plt.show()

# %% [markdown]
# ### Multi Zone Output Comparison - Original BHJet Example

# %%
#for testing:
path_to_bhjet_output = "OG_BHJet_Output/"
bhjet.load_params(path_to_bhjet_output+"Input/ip.dat")
bhjet.run()
output = bhjet.get_output()

mjy = 1.e26
kevconv = 1
dist = bhjet.get_parameter("dist")
fluxconv = 4.*math.pi*(dist*3.*10**21)**2
# Out:
# Inner disk radius: 7.38358e+15 cm, 50 rg; outer disk radius: 1.47672e+17 cm, 1000 rg; disk scale height: 0.1
# Inner disk temperature: 0.00182726 kev; emitted  disk luminosity in Eddington units: 0.01 and erg s^-1: 1.20065e+45
#
# Jet base parameters:
# Pair content (ne/np): 31.3784
# Initial magnetization: 3.61114
# Particle average Lorenz factor: 2.22
# Jet nozzle ends at: 38 Rg
# Jet nozzle optical depth: 0.000462676

# %%
disk_e = np.array([point.energy for point in output.disk])
disk_f = np.array([point.flux for point in output.disk])
Disk = np.genfromtxt(path_to_bhjet_output+"Output/Disk.dat")

presyn_e = np.array([point.energy for point in output.presyn])
presyn_f = np.array([point.flux for point in output.presyn])

postsyn_e = np.array([point.energy for point in output.postsyn])
postsyn_f = np.array([point.flux for point in output.postsyn])

Presyn = np.genfromtxt(path_to_bhjet_output+"Output/Presyn.dat")
Postsyn = np.genfromtxt(path_to_bhjet_output+"Output/Postsyn.dat")

# %%
print("My Code: Presyn Data:", presyn_e[:1], presyn_f[:1])
print("Original Code: Presyn Data:", Presyn[:1])
# Out:
# My Code: Presyn Data: [27292905.4024245] [6.74146745e-08]
# Original Code: Presyn Data: [[2.72929e+07 6.74147e-08]]

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.plot(presyn_e, presyn_e*presyn_f/mjy_conv, linewidth=1.5, color="blue", label="Wrapper")
ax.plot(postsyn_e, postsyn_e*postsyn_f/mjy_conv, linewidth=1.5, color="blue", linestyle='-')

ax.plot(Presyn.T[0],Presyn.T[1]*Presyn.T[0]/mjy_conv,linewidth=1.5, label = "Presyn BHJet", color = 'red', linestyle = '--')
ax.plot(Postsyn.T[0],Postsyn.T[1]*Postsyn.T[0]/mjy_conv,linewidth=1.5, linestyle='--', label = 'Postsyn BHJet', color = 'black')

ax.plot(disk_e, disk_e*disk_f/mjy_conv, linewidth=1.5, color="blue")
ax.plot(Disk.T[0],Disk.T[1]*Disk.T[0]/mjy_conv, color = 'orange', linestyle = '--', label='Disk' )

# ax.set_xlim(1e8, 1e20)
# ax.set_ylim(1e-18, 1e-4)
ax.legend()
ax.grid(True)

ax.set_xlabel(r"Frequency (Hz)",fontsize=12)
ax.set_title("BHJet Example")
ax.set_ylabel(r"Flux (erg/s/cm$^2$)",fontsize=12)
ax.set_xscale('log',base=10)
ax.set_yscale('log',base=10)

# %% [markdown]
# ### Single Zone Example

# %%
# bhjet.run_singlezone()

# %%
# syn_ex = np.genfromtxt("/Users/ruby/Models/BHJet/Examples/Output/Singlezone_Syn.dat")
# com_ex = np.genfromtxt("/Users/ruby/Models/BHJet/Examples/Output/Singlezone_SSC.dat")

# energy = np.array([point.energy for point in output.cyclosyn_zones])
# flux = np.array([point.flux for point in output.cyclosyn_zones])

# e_compton = np.array([point.energy for point in output.compton_zones])
# f_compton = np.array([point.flux for point in output.compton_zones])

# %%
# fig, ax = plt.subplots(figsize=(8, 6))

# ax.plot(energy, energy*flux/mjy ,linewidth=1.5, color="blue", label="Wrapper")
# ax.plot(syn_ex.T[0],syn_ex.T[0]*syn_ex.T[1],linewidth=1.5, label = "Bhjet Example", color = 'red')

# ax.plot(e_compton, e_compton*f_compton/mjy, linewidth=1.5, color="blue")
# ax.plot(com_ex.T[0],com_ex.T[0]*com_ex.T[1],linewidth=1.5, color = 'red')

# ax.set_ylim(1e32, 1e38)
# ax.legend()
# ax.grid(True)

# ax.set_xlabel("Frequency ($\\rm{Hz}$)",fontsize=12)
# ax.set_ylabel("Luminosity ($\\rm{erg\,s^{-1}}$)",fontsize=12)
# ax.set_xscale('log')
# ax.set_yscale('log')
